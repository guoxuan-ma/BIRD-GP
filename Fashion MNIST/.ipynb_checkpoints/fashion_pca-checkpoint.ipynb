# %%
import sys
sys.path.append("../birdgp")

import numpy as np
import matplotlib.pyplot as plt
import math
import bird_gp
import random
import torch
from sklearn.decomposition import PCA
from sklearn import preprocessing

# %matplotlib inline

# %%
train_data = np.loadtxt("fashion-mnist_train.csv", skiprows = 1, delimiter = ",")
test_data = np.loadtxt("fashion-mnist_test.csv", skiprows = 1, delimiter = ",")

# %%
train_img = train_data[:, 1:]
test_img = test_data[:, 1:]
train_label = train_data[:, 0]
test_label = test_data[:, 0]
train_img = train_img / 255
test_img = test_img / 255

train_idx_all = np.arange(60000)
test_idx_all = np.arange(10000)

n = 2000
n_train = 1000
n_test = 1000

num_exp = 50
mse = np.zeros((num_exp, 6))
for exp in range(num_exp):
    random.seed(exp)
    torch.manual_seed(exp)
    np.random.seed(exp)

    #####################################################################
    # generate images
    train_idx = np.random.choice(train_idx_all, size = n_train, replace = False)
    test_idx = np.random.choice(test_idx_all, size = n_test, replace = False)

    train_imgs = train_img[train_idx, ]
    test_imgs = test_img[test_idx, ]
    train_lbs = train_label[train_idx]
    test_lbs = test_label[test_idx]

    train_quantiles = np.zeros((4, n_train))
    for i in range(n_train):
        train_img_i = train_imgs[i, :]
        train_img_i = train_img_i[train_img_i > 0]
        train_quantiles[:, i] = np.quantile(train_img_i, [0, 0.25, 0.5, 0.75])

    train_q0 = np.tile(train_quantiles[0, :].reshape((n_train, 1)), (1, 784))
    train_q1 = np.tile(train_quantiles[1, :].reshape((n_train, 1)), (1, 784))
    train_q2 = np.tile(train_quantiles[2, :].reshape((n_train, 1)), (1, 784))
    train_q3 = np.tile(train_quantiles[3, :].reshape((n_train, 1)), (1, 784))

    train_p0 = np.zeros((n_train, 784))
    train_p1 = np.zeros((n_train, 784))
    train_p2 = np.zeros((n_train, 784))
    train_p3 = np.zeros((n_train, 784))

    train_p3[train_imgs >= train_q3] = train_imgs[train_imgs >= train_q3]
    train_p2[(train_imgs >= train_q2) & (train_imgs < train_q3)] = train_imgs[(train_imgs >= train_q2) & (train_imgs < train_q3)]
    train_p1[(train_imgs >= train_q1) & (train_imgs < train_q2)] = train_imgs[(train_imgs >= train_q1) & (train_imgs < train_q2)]
    train_p0[(train_imgs >= train_q0) & (train_imgs < train_q1)] = train_imgs[(train_imgs >= train_q0) & (train_imgs < train_q1)]

    train_predictors = np.zeros((n_train, 28*28*4))
    train_outcomes = train_imgs
    for i in range(n_train):
        train_p0_i = train_p0[i, :].reshape((28, 28))
        train_p1_i = train_p1[i, :].reshape((28, 28))
        train_p2_i = train_p2[i, :].reshape((28, 28))
        train_p3_i = train_p3[i, :].reshape((28, 28))
        train_predictor_i = np.hstack((train_p0_i, train_p1_i, train_p2_i, train_p3_i))
        train_predictors[i, :] = train_predictor_i.reshape(-1)

    test_quantiles = np.zeros((4, n_test))
    for i in range(n_test):
        test_img_i = test_imgs[i, :]
        test_img_i = test_img_i[test_img_i > 0]
        test_quantiles[:, i] = np.quantile(test_img_i, [0, 0.25, 0.5, 0.75])


    test_q0 = np.tile(test_quantiles[0, :].reshape((n_test, 1)), (1, 784))
    test_q1 = np.tile(test_quantiles[1, :].reshape((n_test, 1)), (1, 784))
    test_q2 = np.tile(test_quantiles[2, :].reshape((n_test, 1)), (1, 784))
    test_q3 = np.tile(test_quantiles[3, :].reshape((n_test, 1)), (1, 784))

    test_p0 = np.zeros((n_test, 784))
    test_p1 = np.zeros((n_test, 784))
    test_p2 = np.zeros((n_test, 784))
    test_p3 = np.zeros((n_test, 784))

    test_p3[test_imgs >= test_q3] = test_imgs[test_imgs >= test_q3]
    test_p2[(test_imgs >= test_q2) & (test_imgs < test_q3)] = test_imgs[(test_imgs >= test_q2) & (test_imgs < test_q3)]
    test_p1[(test_imgs >= test_q1) & (test_imgs < test_q2)] = test_imgs[(test_imgs >= test_q1) & (test_imgs < test_q2)]
    test_p0[(test_imgs >= test_q0) & (test_imgs < test_q1)] = test_imgs[(test_imgs >= test_q0) & (test_imgs < test_q1)]

    test_predictors = np.zeros((n_test, 28*28*4))
    test_outcomes = test_imgs
    for i in range(n_test):
        test_p0_i = test_p0[i, :].reshape((28, 28))
        test_p1_i = test_p1[i, :].reshape((28, 28))
        test_p2_i = test_p2[i, :].reshape((28, 28))
        test_p3_i = test_p3[i, :].reshape((28, 28))
        test_predictor_i = np.hstack((test_p0_i, test_p1_i, test_p2_i, test_p3_i))
        test_predictors[i, :] = test_predictor_i.reshape(-1)
    
    # scaling
    scaler_predictors = preprocessing.StandardScaler().fit(train_predictors)
    scaler_outcomes = preprocessing.StandardScaler().fit(train_outcomes)
    
    train_predictors_scaled = scaler_predictors.transform(train_predictors)
    test_predictors_scaled = scaler_predictors.transform(test_predictors)
    train_outcomes_scaled = scaler_outcomes.transform(train_outcomes)
    test_outcomes_scaled = scaler_outcomes.transform(test_outcomes)
    
    # PCA + SVGD
    pca_train_predictors = PCA(n_components = 650)
    pca_train_predictors.fit(train_predictors_scaled)
    theta_train_predictors = pca_train_predictors.transform(train_predictors_scaled)
    theta_test_predictors = pca_train_predictors.transform(test_predictors_scaled)

    pca_train_outcomes = PCA(n_components = 200)
    pca_train_outcomes.fit(train_outcomes_scaled)
    theta_train_outcomes = pca_train_outcomes.transform(train_outcomes_scaled)
    theta_test_outcomes = pca_train_outcomes.transform(test_outcomes_scaled)

    Psi_outcomes = pca_train_outcomes.components_
    
    model = bird_gp.svgd.svgd_bnn(X_train = theta_train_predictors, 
                                  y_train = theta_train_outcomes,
                                  a_gamma = 1, 
                                  b_gamma = 1, 
                                  a_lambda = 1,
                                  b_lambda = 1000, 
                                  batch_size = 64, 
                                  epochs = 50)
    model.train()
    
    # prediction
    theta_train_outcomes_pred, _ = model.predict(theta_train_predictors)
    train_outcomes_pred = theta_train_outcomes_pred @ Psi_outcomes
    train_pred = scaler_outcomes.inverse_transform(train_outcomes_pred)

    theta_test_outcomes_pred, _ = model.predict(theta_test_predictors)
    test_outcomes_pred = theta_test_outcomes_pred @ Psi_outcomes
    test_pred = scaler_outcomes.inverse_transform(test_outcomes_pred)
    
    mse[exp, 0] = np.mean((train_pred - train_outcomes)**2)
    mse[exp, 1] = np.mean((test_pred - test_outcomes)**2)
    
    
    model = bird_gp.svgd.svgd_bnn(X_train = theta_train_predictors, 
                                  y_train = theta_train_outcomes,
                                  a_gamma = 1, 
                                  b_gamma = 1, 
                                  a_lambda = 1,
                                  b_lambda = 1500, 
                                  batch_size = 64, 
                                  epochs = 50)
    model.train()
    
    # prediction
    theta_train_outcomes_pred, _ = model.predict(theta_train_predictors)
    train_outcomes_pred = theta_train_outcomes_pred @ Psi_outcomes
    train_pred = scaler_outcomes.inverse_transform(train_outcomes_pred)

    theta_test_outcomes_pred, _ = model.predict(theta_test_predictors)
    test_outcomes_pred = theta_test_outcomes_pred @ Psi_outcomes
    test_pred = scaler_outcomes.inverse_transform(test_outcomes_pred)
    
    mse[exp, 2] = np.mean((train_pred - train_outcomes)**2)
    mse[exp, 3] = np.mean((test_pred - test_outcomes)**2)
    
    
    model = bird_gp.svgd.svgd_bnn(X_train = theta_train_predictors, 
                                  y_train = theta_train_outcomes,
                                  a_gamma = 1, 
                                  b_gamma = 1, 
                                  a_lambda = 1,
                                  b_lambda = 2000, 
                                  batch_size = 64, 
                                  epochs = 50)
    model.train()
    
    # prediction
    theta_train_outcomes_pred, _ = model.predict(theta_train_predictors)
    train_outcomes_pred = theta_train_outcomes_pred @ Psi_outcomes
    train_pred = scaler_outcomes.inverse_transform(train_outcomes_pred)

    theta_test_outcomes_pred, _ = model.predict(theta_test_predictors)
    test_outcomes_pred = theta_test_outcomes_pred @ Psi_outcomes
    test_pred = scaler_outcomes.inverse_transform(test_outcomes_pred)
    
    mse[exp, 4] = np.mean((train_pred - train_outcomes)**2)
    mse[exp, 5] = np.mean((test_pred - test_outcomes)**2)
    
    np.savetxt("mse_pca.txt", mse)
# Out:
# epoch: 1 / 50, training rmse: 1.9135, training r2: 0.026
# epoch: 2 / 50, training rmse: 1.8929, training r2: 0.0469
# epoch: 3 / 50, training rmse: 1.8739, training r2: 0.0659
# epoch: 4 / 50, training rmse: 1.8528, training r2: 0.0868
# epoch: 5 / 50, training rmse: 1.8279, training r2: 0.1112
# epoch: 6 / 50, training rmse: 1.7973, training r2: 0.1407
# epoch: 7 / 50, training rmse: 1.7632, training r2: 0.173
# epoch: 8 / 50, training rmse: 1.7208, training r2: 0.2123
# epoch: 9 / 50, training rmse: 1.6748, training r2: 0.2539
# epoch: 10 / 50, training rmse: 1.6239, training r2: 0.2985
# epoch: 11 / 50, training rmse: 1.5675, training r2: 0.3464
# epoch: 12 / 50, training rmse: 1.5092, training r2: 0.3941
# epoch: 13 / 50, training rmse: 1.4489, training r2: 0.4415
# epoch: 14 / 50, training rmse: 1.388, training r2: 0.4875
# epoch: 15 / 50, training rmse: 1.3318, training r2: 0.5282
# epoch: 16 / 50, training rmse: 1.2798, training r2: 0.5643
# epoch: 17 / 50, training rmse: 1.2337, training r2: 0.5951
# epoch: 18 / 50, training rmse: 1.1942, training r2: 0.6206
# epoch: 19 / 50, training rmse: 1.1603, training r2: 0.6419
# epoch: 20 / 50, training rmse: 1.132, training r2: 0.6591
# epoch: 21 / 50, training rmse: 1.1084, training r2: 0.6732
# epoch: 22 / 50, training rmse: 1.09, training r2: 0.6839
# epoch: 23 / 50, training rmse: 1.0737, training r2: 0.6933
# epoch: 24 / 50, training rmse: 1.06, training r2: 0.7011
# epoch: 25 / 50, training rmse: 1.0477, training r2: 0.708
# epoch: 26 / 50, training rmse: 1.0363, training r2: 0.7143
# epoch: 27 / 50, training rmse: 1.0269, training r2: 0.7195
# epoch: 26 / 50, training rmse: 1.0079, training r2: 0.7289
# epoch: 27 / 50, training rmse: 0.9987, training r2: 0.7338
# epoch: 28 / 50, training rmse: 0.9911, training r2: 0.7379
# epoch: 29 / 50, training rmse: 0.9827, training r2: 0.7423
# epoch: 30 / 50, training rmse: 0.9762, training r2: 0.7457
# epoch: 31 / 50, training rmse: 0.9696, training r2: 0.7491
# epoch: 32 / 50, training rmse: 0.964, training r2: 0.752
# epoch: 33 / 50, training rmse: 0.9577, training r2: 0.7552
# epoch: 34 / 50, training rmse: 0.9526, training r2: 0.7578
# epoch: 35 / 50, training rmse: 0.9479, training r2: 0.7602
# epoch: 36 / 50, training rmse: 0.9438, training r2: 0.7623
# epoch: 37 / 50, training rmse: 0.9389, training r2: 0.7647
# epoch: 38 / 50, training rmse: 0.9347, training r2: 0.7669
# epoch: 39 / 50, training rmse: 0.9305, training r2: 0.7689
# epoch: 40 / 50, training rmse: 0.9266, training r2: 0.7709
# epoch: 41 / 50, training rmse: 0.9235, training r2: 0.7724
# epoch: 42 / 50, training rmse: 0.9197, training r2: 0.7743
# epoch: 43 / 50, training rmse: 0.9161, training r2: 0.776
# epoch: 44 / 50, training rmse: 0.9133, training r2: 0.7774
# epoch: 45 / 50, training rmse: 0.9097, training r2: 0.7791
# epoch: 46 / 50, training rmse: 0.9069, training r2: 0.7805
# epoch: 47 / 50, training rmse: 0.9038, training r2: 0.782
# epoch: 48 / 50, training rmse: 0.9012, training r2: 0.7832
# epoch: 49 / 50, training rmse: 0.8984, training r2: 0.7846
# epoch: 50 / 50, training rmse: 0.8959, training r2: 0.7858
# epoch: 1 / 50, training rmse: 1.9114, training r2: 0.025
# epoch: 2 / 50, training rmse: 1.8914, training r2: 0.0453
# epoch: 3 / 50, training rmse: 1.8731, training r2: 0.0637
# epoch: 4 / 50, training rmse: 1.8519, training r2: 0.0847
# epoch: 5 / 50, training rmse: 1.8275, training r2: 0.1087
# epoch: 6 / 50, training rmse: 1.7977, training r2: 0.1375
# epoch: 7 / 50, training rmse: 1.7618, training r2: 0.1716
# epoch: 8 / 50, training rmse: 1.7199, training r2: 0.2106
# epoch: 9 / 50, training rmse: 1.6723, training r2: 0.2537
# epoch: 10 / 50, training rmse: 1.6179, training r2: 0.3014
# epoch: 11 / 50, training rmse: 1.5579, training r2: 0.3523
# epoch: 12 / 50, training rmse: 1.4958, training r2: 0.4029
# epoch: 13 / 50, training rmse: 1.4332, training r2: 0.4518
# epoch: 14 / 50, training rmse: 1.3724, training r2: 0.4973
# epoch: 15 / 50, training rmse: 1.3182, training r2: 0.5363
# epoch: 16 / 50, training rmse: 1.2712, training r2: 0.5687
# epoch: 17 / 50, training rmse: 1.2312, training r2: 0.5954
# epoch: 18 / 50, training rmse: 1.1986, training r2: 0.6166
# epoch: 19 / 50, training rmse: 1.1704, training r2: 0.6344

# %%
mse = np.loadtxt("mse_pca.txt")

# %%
np.mean(mse, 0)
# Out:
# array([0.02026977, 0.0301205 , 0.02563396, 0.03435467, 0.03042636,
#        0.03813039])

# %%
np.std(mse, 0)
# Out:
# array([0.00381997, 0.0039161 , 0.00502832, 0.00412477, 0.0051021 ,
#        0.00465786])
